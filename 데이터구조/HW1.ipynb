# %% [markdown]
# # **온라인 강의 플랫폼 구축하기**
#
# <strong> 과제1번 </strong> <br>
#
#
# 1708164 김종호<br>
#
# 코딩 조력자 : 18학번 송시무

# %% [markdown]
# # 과제1
#
# ---
#
#
#
# 요구사항: OCP 플랫폼에 관련된 Class의 ADT 설계하고 관련된 주요 Methods와 주요 Variables를 구 성하여라. 단, ADT의 구현(Implementation)과 프로그램의 실행은 요구되지 않는다.
# -    OCP Class, Lecture Class, IMDF Class, LDM Class, LR Class, 그리고 PM Class의 ADT를 설
# 계하시오.
# -    OCP  Class는  IMDF,  LDM,  LR,  PM의  클래스의  인스턴스를  포함한다.  4개의  클래스는
# Methods와 Variables이 명확하게 지정되지 않았으나, 생성자는 필요하다.
# - Lecture Class는 OCP 플랫폼 내부의 정보교환을 위한 기본 데이터 모델이다. 그림 2를 참고 하여, 학생들은 ADT Class를 완성하시기 바랍니다. Class 설계 시, 학생들은 Variable names 을 그림 2의 대응되는 항목명(영문)의 값과 일치되도록 작성해야만 합니다. 선언된 Variable은 항목명에 대한 주석이 꼭 필요합니다, 예) blocks_url # 강좌 URL
#
# ◼  샘플데이터(https://www.data.go.kr/data/15042355/openapi.do)를  사용하여  인스턴 스를 생성해야함. 예) lecture1 = Lecture(…, …, …)
#
# ◼         print(lecture1)은 강좌아이디, 강좌명과 강좌URL만을 출력해야 함

# %%
class OCP:
  '''
   Online Course Platform 클래스
  '''
  def __init__(self):
    self.LR=LR()
    self.IMDF=IMDF()
    self.LDM=LDM()
    self.PM=PM()
    # ocp는 IMDF, LDM, LR, PM 의 클래스의 인스턴스 포함.

  # 강의 수집
  def collect_lectures(self, platform="KMOOC"):
    '''
    @param platorm : 수집하고자 하는 강의 플랫폼
    return
    '''
    pass

  # 강의자료 저장
  def store_lectures(self, lectures):
    '''
    @param lectures : 강의 데이터 (리스트 타입)
    return
    '''
    pass

  #강의자료 분석
  def analysis_lectures(self,lectures):
    '''
    @param lectures : 강의 데이터 (리스트 타입)
    return
    '''
    pass

  #강의자료 비교
  def comparison_lectures(self,lectures,codition):
    '''
    @param lectures : 강의 데이터 (리스트 타입)
    @param codition : 비교조건
    return
    '''
    pass




class Lecture:
  '''
   OCP 플랫폼 내부의 정보교환을 위한 기본 데이터 모델
  '''
  #생성자
  def __init__(self, block_url,effort,End,enrollment_start,enrollment_end,id,course_image,name,Number,org,short_description,start,start_display,start_type,Pacing,mobile_available,hidden):
    self.block_url=block_url # 강좌 URL
    self.effort=effort # 강좌주요시간
    self.End=End #강좌 종료일
    self.enrollment_start=enrollment_start #수강신청 시작일
    self.enrollment_end=enrollment_end #수강신청 종료일
    self.id=id #강좌 아이디
    self.course_image=course_image #강좌 이미지
    self.name=name #강좌명
    self.Number=Number #강좌번호
    self.org=org #기관명
    self.short_description=short_description #짧은 소개
    self.start=start #강좌 시작일
    self.start_display=start_display #강좌 시작일 표시문구
    self.start_type=start_type #강좌 시작일 표시 형식
    self.Pacing=Pacing #강좌 형식
    self.mobile_available=mobile_available #모바일 지원여부
    self.hidden=hidden #강좌 감춤여부
    # ...
  #강좌 아이디, 강좌명과 강좌 URL 출력
  def __str__(self):
    return f" 강좌 URL: { self.block_url}, 강좌아이디 : {self.id}, 강좌명 : {self.name} "


class IMDF:
  '''
  인메모리 데이터 패프릭
  강의 데이터를 관리하는 다양한 종류의 데이터 구조를 제공하는 컴포넌트
  '''
  def __init__(self):
   pass
  
  def List(self,lectures): # List 기반 데이터구조
    '''
    @param lectures : 강의 데이터 (리스트 타입)
    return
    '''

  def Map(self,lectures): #map기반 데이터구조
    '''
    @param lectures : 강의 데이터 
    return
    '''
    pass

  def Tree(self,lectures): # Tree기반 데이터구조
   '''
    @param lectures : 강의 데이터
    return
   '''
  pass

  def Hash_Table(self,lectures): # Hash기반 데이터구조
    '''
    @param lectures : 강의 데이터 
    return
   ''' 
  pass

  def Queue(self): #Queue기반 데이터구조
    '''
    @param lectures : 강의 데이터 
    return
   ''' 
  pass


class LDM:
  '''
  대응되는 데이터 구조에 따라 강의데이터를 검색, 정렬, 추가, 삭제가 가능한 컴포넌트
  '''
  def __init__(self):
   pass
  
  def search(self,condition,lectures): #검색
    '''
    @param condition : 검색할 조건
    @param lectures :  강의 데이터 (리스트 타입)
    return
    '''
    pass

  def sort(self,data_structure,lectures): #정렬
    '''
    @param data_structer : 어떻게 정렬할 것인지에 대한 데이터 구조
    @param lectures :  강의 데이터 (리스트 타입)
    return
    '''
    pass

  def add(self,data,lectures): #추가
    '''
    @param data : 추가하고자 하는 강의
    @param lectures :  강의 데이터 
    '''
    pass

  def delete(self,data,lectures): #삭제
    '''
    @param data : 삭제하고자 하는 강의
    @param lectures :  강의 데이터 
    return
    '''
    pass   

class LR:
  
 '''
 강의 데이터 조작 모듈과 함께 적절한 강의 데이터를 추천하는 컴포넌트
 '''
 def __init__(self):
    self.LDM=LDM()
    pass
 def recommend_Item_Based_lectures(self,lectures): 
   #사용자가 들었던 강의과 비슷한 강의를 추천해주는 강의
   self.LDM.search()
   '''
    return
   '''
 def recommend_Similarity_Based_lectures(self,lectures): 
 #사용자가 특정 강의를 선호하는 경우 그 강의와 비슷한 키워드를 가진 다른 강의를 추천해주는  방식.
   self.LDM.search()
   '''
    return
   '''      



class PM:
  '''
  OCP 플랫폼에서 동작하는 컴포넌트의 성능을 수행시간 측면에서 모니터링하고 가장 성능이 좋은 알고리즘을 확인
  '''
  def Monitoring_component(self,program):
    '''
    @param program : 성능을 측정할 프로그램
    '''
  def __init__(self):
   pass

# %%
kmooc_lec1= Lecture("http://www.kmooc.kr/api/courses/v1/blocks/?course_id=course-v1%3AFUNMOOC%2Btest1%2Btest1","09:08@07#04:03$06:05","2031-01-01T00:00:00Z","	2030-01-02T00:00:00Z","2031-01-01T00:00:00Zㅍ","course-v1:FUNMOOC+test1+test1","http://www.kmooc.kr/asset-v1:FUNMOOC+test1+test1+type@asset+block@images_course_image.jpg","강좌생성테스트","	test1","	FUNMOOC","강좌의 짧은소개","	2030-01-02T00:00:00Z","2030년 1월 2일","Timestamp","pacing","1",'False')
print(kmooc_lec1)
# Out:
#  강좌 URL: http://www.kmooc.kr/api/courses/v1/blocks/?course_id=course-v1%3AFUNMOOC%2Btest1%2Btest1, 강좌아이디 : course-v1:FUNMOOC+test1+test1, 강좌명 : 강좌생성테스트
